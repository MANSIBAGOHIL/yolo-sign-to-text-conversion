# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 plots=True
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.11.9 torch-2.2.2+cpu CPU (Intel Core(TM) i5-10300H 2.50GHz)
# ...

# %%
# !ls runs/detect/train7/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !yolo task=detect mode=val model=runs/detect/train7/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.11.9 torch-2.2.2+cpu CPU (Intel Core(TM) i5-10300H 2.50GHz)
# Model summary (fused): 168 layers, 11136033 parameters, 0 gradients, 28.5 GFLOPs
#                    all        130        130      0.941      0.967      0.957      0.892
#                      O        130         15      0.992          1      0.995      0.945
#                      P        130         20          1      0.769       0.99      0.924
#                      Q        130         15      0.992          1      0.995      0.941
#                      R        130         15      0.991          1      0.995      0.934
#                      S        130         15      0.875          1      0.935      0.856
#                      T        130         15      0.988      0.867      0.922       0.86
#                      U        130         15      0.991          1      0.995      0.905
#                      V        130          5      0.607          1      0.711      0.687
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.25 source='D:\project\Test\images\all'
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.11.9 torch-2.2.2+cpu CPU (Intel Core(TM) i5-10300H 2.50GHz)
# Model summary (fused): 168 layers, 11136033 parameters, 0 gradients, 28.5 GFLOPs
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\cfg\__init__.py", line 582, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py", line 452, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
